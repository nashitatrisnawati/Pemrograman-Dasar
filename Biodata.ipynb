# %% [markdown]
# <a href="https://colab.research.google.com/github/nashitatrisnawati/Pemrograman-Dasar/blob/main/Biodata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Nashita"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = 'Pemrograman Dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Nashita
# 19
# RPE
# 3
# Pemrograman Dasar
# False
