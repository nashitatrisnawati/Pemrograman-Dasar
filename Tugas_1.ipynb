# %% [markdown]
# <a href="https://colab.research.google.com/github/nashitatrisnawati/Pemrograman-Dasar/blob/main/Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "Nashita Trisnawati"
umur = "19 tahun"
jurusan = "Teknik Elektro"
prodi = "Teknologi Rekayasa Pembangkit Energi"
semester = 3
matakuliah = 'Pemrograman Dasar'
alamat = "Perum. Taman Surya Indah Blok Q no 2"
hobi = "cabut rumput"
warna_kesukaan = 'biru'
status_kelulusan = False

print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (alamat)
print (hobi)
print (warna_kesukaan)
print (status_kelulusan)
# Out:
# Nashita Trisnawati
# 19 tahun
# Teknik Elektro
# Teknologi Rekayasa Pembangkit Energi
# 3
# Pemrograman Dasar
# Perum. Taman Surya Indah Blok Q no 2
# cabut rumput
# biru
# False
